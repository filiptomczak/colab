# %% [markdown]
# <a href="https://colab.research.google.com/github/filiptomczak/colab/blob/main/intro/pandas_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame(data=[10,19,31],index=['first','second','third'],columns=['col_1'])
df
# Out:
#         col_1
# first      10
# second     19
# third      31

# %%
df=pd.DataFrame(data={'wig20':['pkn_orlen','pko bp'],
                      'wig40':['amica','neonet']})

df
# Out:
#        wig20   wig40
# 0  pkn_orlen   amica
# 1     pko bp  neonet

# %%
df=pd.DataFrame(data=[[10,19,31],[10,12,14]],index=['first','second'],columns=['col_1','col_2','col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     19     31
# second     10     12     14

# %%
df.columns
df.index
df.values
# Out:
# array([[10, 19, 31],
#        [10, 12, 14]])

# %%
df['col_1'] #series
df[['col_1']] #dataframe
# Out:
# first     10
# second    10
# Name: col_1, dtype: int64

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns=['a','b','c']
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.a
# Out:
# first     10
# second    10
# Name: a, dtype: int64

# %%
df
# Out:
#          a   b   c
# first   10  19  31
# second  10  12  14

# %% [markdown]
# wyciecie indeksu

# %%
a=df.loc['first']
a
# Out:
# a    10
# b    19
# c    31
# Name: first, dtype: int64

# %%
df.iloc[1]
# Out:
# a    10
# b    12
# c    14
# Name: second, dtype: int64
